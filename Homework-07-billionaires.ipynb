# %%
import pandas as pd

# %%
df = pd.read_excel("richpeople.xlsx")

# %%
df.head()
# Out:
#    year                         name  rank           citizenship countrycode  \
# 0  2001          A Jerrold Perenchio   151         United States         USA
# 1  2014         A. Jerrold Perenchio   663         United States         USA
# 2  2001  Abdul Al Rahman  Al Jeraisy   336          Saudi Arabia         SAU
# 3  2001        Abdul Aziz Al Ghurair   251  United Arab Emirates         ARE
# 4  1996       Abdul Aziz Al-Sulaiman   404          Saudi Arabia         SAU
#
#    networthusbillion   selfmade         typeofwealth gender   age   ...     \
# 0                3.0  self-made            executive   male  70.0   ...
# 1                2.6  self-made            executive   male  83.0   ...
# 2                1.5  self-made  founder non-finance   male   NaN   ...
# 3                1.9  inherited            inherited   male  47.0   ...
# 4                1.0  self-made    self-made finance   male   0.0   ...
#
# ...

# %%
df.columns
# Out:
# Index(['year', 'name', 'rank', 'citizenship', 'countrycode',
#        'networthusbillion', 'selfmade', 'typeofwealth', 'gender', 'age',
#        'industry', 'IndustryAggregates', 'region', 'north',
#        'politicalconnection', 'founder', 'generationofinheritance', 'sector',
#        'company', 'companytype', 'relationshiptocompany', 'foundingdate',
#        'gdpcurrentus', 'sourceofwealth', 'notes', 'notes2', 'source',
#        'source_2', 'source_3', 'source_4'],
#       dtype='object')

# %%
recent = df[df['year'] == 2014]
recent.head()
# Out:
#    year                          name  rank           citizenship countrycode  \
# 1  2014          A. Jerrold Perenchio   663         United States         USA
# 5  2014            Abdulla Al Futtaim   687  United Arab Emirates         ARE
# 6  2014  Abdulla bin Ahmad Al Ghurair   305  United Arab Emirates         ARE
# 8  2014             Abdullah Al Rajhi   731          Saudi Arabia         SAU
# 9  2014              Abdulsamad Rabiu  1372               Nigeria         NGA
#
#    networthusbillion   selfmade         typeofwealth gender   age   ...     \
# 1                2.6  self-made            executive   male  83.0   ...
# 5                2.5  inherited            inherited   male   NaN   ...
# 6                4.8  inherited            inherited   male   NaN   ...
# 8                2.4  self-made    self-made finance   male   NaN   ...
# 9                1.2  self-made  founder non-finance   male  54.0   ...
#
#      relationshiptocompany foundingdate gdpcurrentus  \
# ...

# %% [markdown]
# #### 1. What country are most billionaires from? For the top ones, how many billionaires per billion people?

# %%
recent['countrycode'].value_counts()
# Out:
# USA       499
# CHN       152
# RUS       111
# DEU        85
# BRA        65
# IND        56
# GBR        47
# HKG        45
# FRA        43
# ITA        35
# CAN        32
# AUS        29
# Taiwan     28
# KOR        27
# JPN        27
# ESP        26
# TUR        24
# CHE        22
# IDN        19
# SWE        19
# ISR        18
# MEX        16
# SGP        16
# MYS        13
# CHL        12
# THA        11
# AUT        10
# PHL        10
# NOR         9
# UKR         9
#          ...
# POL         5
# IRL         5
# FIN         5
# KAZ         5
# KWT         5
# ARE         4
# CYP         4
# NGA         4
# COL         4
# MAR         4
# BEL         3
# MCO         3
# VEN         3
# PRT         3
# GRC         3
# OMN         2
# NZL         2
# MAC         2
# TZA         1
# SWZ         1
# NPL         1
# VNM         1
# UGA         1
# AGO         1
# ROU         1
# GGY         1
# KNA         1
# GEO         1
# LTU         1
# DZA         1
# ...

# %%
# how many billionaires per billion people?

# %% [markdown]
# #### 2. Who are the top 10 richest billionaires?

# %%
top_bill = recent.sort_values('networthusbillion', ascending=False).head(10)
top_bill
# Out:
#       year              name  rank    citizenship countrycode  \
# 284   2014        Bill Gates     1  United States         USA
# 348   2014  Carlos Slim Helu     2         Mexico         MEX
# 124   2014    Amancio Ortega     3          Spain         ESP
# 2491  2014    Warren Buffett     4  United States         USA
# 1377  2014     Larry Ellison     5  United States         USA
# 509   2014        David Koch     6  United States         USA
# 381   2014      Charles Koch     6  United States         USA
# 2185  2014   Sheldon Adelson     8  United States         USA
# 429   2014    Christy Walton     9  United States         USA
# 1128  2014        Jim Walton    10  United States         USA
#
#       networthusbillion   selfmade              typeofwealth  gender   age  \
# 284                76.0  self-made       founder non-finance    male  58.0
# 348                72.0  self-made  privatized and resources    male  74.0
# ...

# %%
# poorest
recent.sort_values(by='rank', ascending=False).head()
# Out:
#       year                 name  rank     citizenship countrycode  \
# 1971  2014        Richard Chang  1565          Taiwan      Taiwan
# 1834  2014          Pavel Tykac  1565  Czech Republic         CZE
# 2443  2014  Vivek Chaand Sehgal  1565       Australia         AUS
# 1656  2014         Michael Kors  1565   United States         USA
# 1089  2014         Jeanine Dick  1565          France         FRA
#
#       networthusbillion   selfmade              typeofwealth  gender   age  \
# 1971                1.0  self-made         self-made finance    male  67.0
# 1834                1.0  self-made  privatized and resources    male  49.0
# 2443                1.0  self-made       founder non-finance    male  57.0
# 1656                1.0  self-made       founder non-finance    male  54.0
# 1089                1.0  inherited                 inherited  female  77.0
#
#                             ...                         relationshiptocompany  \
# ...

# %% [markdown]
# #### 3. What's the average wealth of a billionaire? Male? Female?

# %%
recent['networthusbillion'].describe()
# Out:
# count    1653.000000
# mean        3.904658
# std         5.748520
# min         1.000000
# 25%         1.400000
# 50%         2.100000
# 75%         3.700000
# max        76.000000
# Name: networthusbillion, dtype: float64

# %%
#average?

# %%
male = recent[recent['gender'] == "male"]
male.head()
# or recent.groupy('gender')['networthusbillion'].describe
# Out:
#    year                          name  rank           citizenship countrycode  \
# 1  2014          A. Jerrold Perenchio   663         United States         USA
# 5  2014            Abdulla Al Futtaim   687  United Arab Emirates         ARE
# 6  2014  Abdulla bin Ahmad Al Ghurair   305  United Arab Emirates         ARE
# 8  2014             Abdullah Al Rajhi   731          Saudi Arabia         SAU
# 9  2014              Abdulsamad Rabiu  1372               Nigeria         NGA
#
#    networthusbillion   selfmade         typeofwealth gender   age   ...     \
# 1                2.6  self-made            executive   male  83.0   ...
# 5                2.5  inherited            inherited   male   NaN   ...
# 6                4.8  inherited            inherited   male   NaN   ...
# 8                2.4  self-made    self-made finance   male   NaN   ...
# 9                1.2  self-made  founder non-finance   male  54.0   ...
#
#      relationshiptocompany foundingdate gdpcurrentus  \
# ...

# %%
male['networthusbillion'].describe() #average?
# Out:
# count    1473.000000
# mean        3.902716
# std         5.801227
# min         1.000000
# 25%         1.400000
# 50%         2.100000
# 75%         3.700000
# max        76.000000
# Name: networthusbillion, dtype: float64

# %%
female = recent[recent['gender'] == "female"]
male['networthusbillion'].describe()
# Out:
# count    1473.000000
# mean        3.902716
# std         5.801227
# min         1.000000
# 25%         1.400000
# 50%         2.100000
# 75%         3.700000
# max        76.000000
# Name: networthusbillion, dtype: float64

# %% [markdown]
# #### 4. Most common source of wealth? Male vs. female?`

# %%
most_common = recent['sourceofwealth'].value_counts().head() 
most_common
# Out:
# real estate        107
# diversified         69
# retail              63
# investments         60
# pharmaceuticals     42
# Name: sourceofwealth, dtype: int64

# %%
male['sourceofwealth'].value_counts().head()
# Out:
# real estate        100
# diversified         60
# retail              60
# investments         58
# pharmaceuticals     40
# Name: sourceofwealth, dtype: int64

# %%
female['sourceofwealth'].value_counts().head()
# Out:
# diversified            9
# real estate            7
# media                  6
# construction           5
# hotels, investments    5
# Name: sourceofwealth, dtype: int64

# %%
recent.groupby('industry')['networthusbillion'].sum().sort_values(ascending=False)
# Out:
# industry
# Consumer                           1177.8
# Retail, Restaurant                  820.9
# Technology-Computer                 684.6
# Diversified financial               614.4
# Real Estate                         573.8
# Media                               490.5
# Money Management                    381.3
# Energy                              340.5
# Non-consumer industrial             298.4
# Mining and metals                   240.6
# Technology-Medical                  218.0
# Other                               179.3
# Constrution                         175.4
# Hedge funds                         167.2
# Private equity/leveraged buyout      71.9
# Venture Capital                      11.1
# 0                                     7.6
# Name: networthusbillion, dtype: float64

# %% [markdown]
# #### 5. Given the richest person in a country, what % of the GDP is their wealth?

# %%
recent.groupby('countrycode')['networthusbillion'].sum().sort_values(ascending=False)
# Out:
# countrycode
# USA       2322.4
# RUS        422.5
# DEU        401.4
# CHN        375.8
# FRA        235.3
# HKG        213.7
# BRA        192.2
# IND        191.9
# ITA        158.1
# GBR        152.0
# MEX        142.9
# ESP        122.6
# SWE        116.7
# CAN        112.8
# JPN        101.0
# AUS         85.4
# CHE         80.2
# Taiwan      75.8
# KOR         60.7
# MYS         53.1
# ISR         51.8
# SAU         49.0
# IDN         47.8
# SGP         45.1
# TUR         43.2
# CHL         41.3
# PHL         40.1
# THA         36.8
# AUT         33.8
# NGA         33.3
#            ...
# EGY         15.6
# ARE         14.6
# FIN         13.3
# POL         12.8
# LBN         12.3
# PER         11.9
# ARG         11.3
# PRT         10.6
# NZL          9.8
# KAZ          9.2
# VEN          9.0
# GRC          8.2
# BEL          8.0
# MAR          7.4
# KWT          6.5
# GEO          5.2
# MCO          4.6
# SWZ          3.7
# AGO          3.7
# DZA          3.2
# MAC          2.8
# ...

# %%
usa_gdp = 7419  
richest = 76 
percent = round(richest / usa_gdp * 100,2)
print(percent, "% of the US GDP is his wealth.")
# Out:
# 1.02 % of the US GDP is his wealth.

# %% [markdown]
# #### 6. How many self made billionaires vs. others?

# %%
recent['selfmade'].value_counts()
# Out:
# self-made    1146
# inherited     505
# Name: selfmade, dtype: int64

# %% [markdown]
# #### 7. How old are billionaires? How old are billionaires self made vs. non self made? or different industries?

# %%
columns_want = recent[['name', 'age', 'selfmade','industry']]
columns_want.head()
# Out:
#                            name   age   selfmade               industry
# 1          A. Jerrold Perenchio  83.0  self-made                  Media
# 5            Abdulla Al Futtaim   NaN  inherited     Retail, Restaurant
# 6  Abdulla bin Ahmad Al Ghurair   NaN  inherited  Diversified financial
# 8             Abdullah Al Rajhi   NaN  self-made       Money Management
# 9              Abdulsamad Rabiu  54.0  self-made               Consumer

# %% [markdown]
# #### 8. Who are the youngest billionaires? The oldest? Age distribution - maybe make a graph about it?

# %%
youngest = recent.sort_values('age').head()
youngest
# Out:
#       year                 name  rank    citizenship countrycode  \
# 1838  2014          Perenna Kei  1284      Hong Kong         HKG
# 605   2014     Dustin Moskovitz   202  United States         USA
# 1586  2014      Mark Zuckerberg    21  United States         USA
# 189   2014  Anton Kathrein, Jr.  1270        Germany         DEU
# 602   2014         Drew Houston  1372  United States         USA
#
#       networthusbillion   selfmade         typeofwealth  gender   age  \
# 1838                1.3  inherited            inherited  female  24.0
# 605                 6.8  self-made  founder non-finance    male  29.0
# 1586               28.5  self-made  founder non-finance    male  29.0
# 189                 1.4  inherited            inherited    male  29.0
# 602                 1.2  self-made  founder non-finance    male  30.0
#
#        ...    relationshiptocompany foundingdate gdpcurrentus  sourceofwealth  \
# ...

# %%
oldest = recent.sort_values('age', ascending=False).head()
oldest
# Out:
#       year                    name  rank    citizenship countrycode  \
# 516   2014  David Rockefeller, Sr.   580  United States         USA
# 1277  2014           Karl Wlaschek   305        Austria         AUT
# 1328  2014          Kirk Kerkorian   328  United States         USA
# 921   2014           Henry Hillman   687  United States         USA
# 666   2014      Erika Pohl-Stroher  1154        Germany         DEU
#
#       networthusbillion   selfmade         typeofwealth  gender   age  \
# 516                 2.9  inherited            inherited    male  98.0
# 1277                4.8  self-made  founder non-finance    male  96.0
# 1328                4.5  self-made    self-made finance    male  96.0
# 921                 2.5  inherited            inherited    male  95.0
# 666                 1.5  inherited            inherited  female  95.0
#
#        ...    relationshiptocompany foundingdate gdpcurrentus  \
# 516    ...                 relation       1870.0          NaN
# ...

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
plt.style.available
# Out:
# ['seaborn-ticks',
#  'seaborn-colorblind',
#  'seaborn-whitegrid',
#  'grayscale',
#  'seaborn-deep',
#  'bmh',
#  'fivethirtyeight',
#  'seaborn-muted',
#  'seaborn-poster',
#  'seaborn-dark-palette',
#  'ggplot',
#  'seaborn-dark',
#  'seaborn-bright',
#  'seaborn-darkgrid',
#  'seaborn-pastel',
#  'classic',
#  'seaborn-paper',
#  'seaborn-white',
#  'seaborn-talk',
#  'seaborn-notebook',
#  'dark_background']

# %%
#plt.style.available
plt.style.use("ggplot")
sorted_young= recent[recent['age']<40].sort_values(by='networthusbillion', ascending=False)
sorted_young.plot(kind = 'barh', x='name', y='networthusbillion')

# %% [markdown]
# #### 9. Plot their net worth vs age (scatterplot)

# %%
recent.plot(kind='scatter', x='age', y='networthusbillion')

# %% [markdown]
# #### 10. Make a bar graph of the top 10 or 20 richest

# %%
recent['networthusbillion'].head(10).plot(kind='bar', x='name', y='networthusbillion')
